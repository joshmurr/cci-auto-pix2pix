# %% [markdown]
# <a href="https://colab.research.google.com/github/joshmurr/cci-auto-pix2pix/blob/master/pix2pix_fungus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/joshmurr/cci-auto-pix2pix
# Out:
# Cloning into 'cci-auto-pix2pix'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 50 (delta 18), reused 45 (delta 13), pack-reused 0
# Unpacking objects: 100% (50/50), done.

# %%
# !sudo wget https://yt-dl.org/downloads/latest/youtube-dl -O /usr/local/bin/youtube-dl
# !sudo chmod a+rx /usr/local/bin/youtube-dl
# !youtube-dl -U
# Out:
# --2020-09-10 09:17:21--  https://yt-dl.org/downloads/latest/youtube-dl
# Resolving yt-dl.org (yt-dl.org)... 95.143.172.170, 2001:1a50:11:0:5f:8f:acaa:177
# Connecting to yt-dl.org (yt-dl.org)|95.143.172.170|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://yt-dl.org/downloads/2020.09.06/youtube-dl [following]
# --2020-09-10 09:17:21--  https://yt-dl.org/downloads/2020.09.06/youtube-dl
# Connecting to yt-dl.org (yt-dl.org)|95.143.172.170|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/ytdl-org/youtube-dl/releases/download/2020.09.06/youtube-dl [following]
# --2020-09-10 09:17:21--  https://github.com/ytdl-org/youtube-dl/releases/download/2020.09.06/youtube-dl
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !youtube-dl -U
# Out:
# youtube-dl is up-to-date (2020.09.06)

# %%
# !youtube-dl -F CvfLSv0sfb0
# Out:
# [youtube] CvfLSv0sfb0: Downloading webpage
# [info] Available formats for CvfLSv0sfb0:
# format code  extension  resolution note
# 249          webm       audio only tiny   61k , opus @ 50k (48000Hz), 1.89MiB
# 250          webm       audio only tiny   80k , opus @ 70k (48000Hz), 2.48MiB
# 140          m4a        audio only tiny  128k , m4a_dash container, mp4a.40.2@128k (44100Hz), 4.47MiB
# 251          webm       audio only tiny  151k , opus @160k (48000Hz), 4.81MiB
# 278          webm       256x144    144p   97k , webm container, vp9, 25fps, video only, 2.83MiB
# 160          mp4        256x144    144p  103k , avc1.4d400c, 25fps, video only, 1.32MiB
# 133          mp4        426x240    240p  210k , avc1.4d4015, 25fps, video only, 2.37MiB
# 242          webm       426x240    240p  224k , vp9, 25fps, video only, 4.06MiB
# 243          webm       640x360    360p  409k , vp9, 25fps, video only, 7.16MiB
# ...

# %%
# !youtube-dl -f 134 -o 'fungus.%(ext)s' CvfLSv0sfb0
# Out:
# [youtube] CvfLSv0sfb0: Downloading webpage
# [download] Destination: fungus.mp4
# [download] 100% of 5.86MiB in 00:00

# %%
# Trim off the presenter at the end of the video
# !ffmpeg -i fungus.mp4 -ss 00:00 -to 04:22 -codec copy fungus_trimmed.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# !mkdir cci-auto-pix2pix/dataset
# !sudo chmod u+x ./cci-auto-pix2pix/frame_extractor.sh
# !sudo apt install bc
# Out:
# mkdir: cannot create directory ‘cci-auto-pix2pix/dataset’: File exists
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# bc is already the newest version (1.07.1-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
# !cci-auto-pix2pix/frame_extractor.sh ./fungus_trimmed.mp4 ./cci-auto-pix2pix/dataset 1000 -1:256
# Out:
# Video "fungus_trimmed.mp4" is 256.880000 seconds long.
# Extracting 1000 frames from ./fungus_trimmed.mp4 every .25688000000000000000 seconds.
#
# Resizing images to a -1:256 scale.
# [swscaler @ 0x5624c4c44000] deprecated pixel format used, make sure you did set range correctly
# cci-auto-pix2pix/frame_extractor.sh: line 38: identify: command not found
# [swscaler @ 0x5581277fc000] deprecated pixel format used, make sure you did set range correctly
# date: invalid date ‘@.25688000000000000000’
# Invalid duration specification for ss:
# date: invalid date ‘@.51376000000000000000’
# Invalid duration specification for ss:
# date: invalid date ‘@.77064000000000000000’
# Invalid duration specification for ss:
# [swscaler @ 0x55a3d7140000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55799ec1c000] deprecated pixel format used, make sure you did set range correctly
# ...

# %%
# !ls -l ./cci-auto-pix2pix/dataset | wc -l
# Out:
# 1003

# %%
# !python3 ./cci-auto-pix2pix/main.py -n fungus -e 50 -d ./cci-auto-pix2pix/dataset
# Out:
# Using fungus for the model name and directories.
#
# Checking files in dataset directory...
#
# 	- Creating ./cci-auto-pix2pix/dataset/train
# 	- Creating ./cci-auto-pix2pix/dataset/test
# 	- Found 1002 files with the extensions:{'.jpg'}
# 	- Only .jpg images will be used.
# 	- Splitting dataset 4:1 into ./cci-auto-pix2pix/dataset/train and ./cci-auto-pix2pix/dataset/test respectively.
# Using provided Batch Size of 4
#
# Using provided Buffer Size of 1000
#
#         PROGRAM	--- DETAILS
# --------------	--- --------------
#            NAME	--- fungus
#    DATASET_PATH	--- ./cci-auto-pix2pix/dataset
#     BUFFER_SIZE	--- 1000
#      BATCH_SIZE	--- 4
#          EPOCHS	--- 50
#
# Importing Tensorflow...
# 2020-09-10 09:25:09.456049: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Creating Dataset...
# {'name': 'fungus', 'dataset_path': './cci-auto-pix2pix/dataset', 'buffer_size': 1000, 'batch_size': 4}
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# 4/3wGRkqhqk4EGndC5szbUaxZFtR49xCZIY-MSYi47D-gRlyw8421KILs
# Mounted at /content/drive

# %%
# !cp -r ./fungus  /content/drive/My\ Drive/
